# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
FL_Places = gpd.read_file("cb_2024_12_place_500k.shp")
print(FL_Places)
# Out:
#     STATEFP PLACEFP   PLACENS           GEOIDFQ    GEOID               NAME  \
# 0        12   53150  02404445  1600000US1253150  1253150       Ormond Beach
# 1        12   37775  02404863  1600000US1237775  1237775          Lake City
# 2        12   44075  02406143  1600000US1244075  1244075  Melbourne Village
# 3        12   26075  02406577  1600000US1226075  1226075      Glen St. Mary
# 4        12   35850  02405926  1600000US1235850  1235850         Juno Beach
# ..      ...     ...       ...               ...      ...                ...
# 951      12   45350  02403285  1600000US1245350  1245350         Middleburg
# 952      12   04975  02405231  1600000US1204975  1204975               Bell
# 953      12   57908  02583376  1600000US1257908  1257908        Point Baker
# 954      12   73725  02402960  1600000US1273725  1273725               Vamo
# 955      12   25987  02402526  1600000US1225987  1225987          Gladeview
#
#                    NAMELSAD STUSPS STATE_NAME LSAD     ALAND    AWATER  \
# 0         Ormond Beach city     FL    Florida   25  90951810  10688642
# 1            Lake City city     FL    Florida   25  37050337   1115873
# 2    Melbourne Village town     FL    Florida   43   1505618         0
# 3        Glen St. Mary town     FL    Florida   43   1185744         0
# 4           Juno Beach town     FL    Florida   43   5289536   1765874
# ..                      ...    ...        ...  ...       ...       ...
# 951          Middleburg CDP     FL    Florida   57  50806298         0
# 952               Bell town     FL    Florida   43   4242166         0
# 953         Point Baker CDP     FL    Florida   57  17131119     40093
# 954                Vamo CDP     FL    Florida   57   2018358    825433
# 955           Gladeview CDP     FL    Florida   57   6629203     13777
#
#                                               geometry
# 0    MULTIPOLYGON (((-81.13629 29.35995, -81.13167 ...
# 1    POLYGON ((-82.70968 30.18463, -82.70968 30.184...
# 2    POLYGON ((-80.6712 28.0927, -80.66728 28.09272...
# 3    POLYGON ((-82.16666 30.2784, -82.16363 30.2789...
# 4    POLYGON ((-80.07281 26.89144, -80.07065 26.891...
# ..                                                 ...
# 951  POLYGON ((-81.94405 30.00219, -81.93143 30.012...
# 952  POLYGON ((-82.87489 29.76695, -82.86647 29.767...
# 953  POLYGON ((-87.07917 30.68657, -87.0786 30.7041...
# 954  POLYGON ((-82.50492 27.22895, -82.50088 27.230...
# 955  POLYGON ((-80.25811 25.8455, -80.24991 25.8457...
#
# [956 rows x 13 columns]

# %%
city_name = FL_Places[['NAME']]
city_limit = FL_Places[['geometry']]
print(city_name, city_limit)
# Out:
#                   NAME
# 0         Ormond Beach
# 1            Lake City
# 2    Melbourne Village
# 3        Glen St. Mary
# 4           Juno Beach
# ..                 ...
# 951         Middleburg
# 952               Bell
# 953        Point Baker
# 954               Vamo
# 955          Gladeview
#
# [956 rows x 1 columns]                                               geometry
# 0    MULTIPOLYGON (((-81.13629 29.35995, -81.13167 ...
# 1    POLYGON ((-82.70968 30.18463, -82.70968 30.184...
# 2    POLYGON ((-80.6712 28.0927, -80.66728 28.09272...
# 3    POLYGON ((-82.16666 30.2784, -82.16363 30.2789...
# 4    POLYGON ((-80.07281 26.89144, -80.07065 26.891...
# ..                                                 ...
# 951  POLYGON ((-81.94405 30.00219, -81.93143 30.012...
# 952  POLYGON ((-82.87489 29.76695, -82.86647 29.767...
# 953  POLYGON ((-87.07917 30.68657, -87.0786 30.7041...
# 954  POLYGON ((-82.50492 27.22895, -82.50088 27.230...
# 955  POLYGON ((-80.25811 25.8455, -80.24991 25.8457...
#
# [956 rows x 1 columns]

# %%
city_limit.plot()
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(10, 10))
city_limit.plot(ax=ax, color='white', edgecolor='black')
plt.show()

# %%
city_limit.area
# Out:
# C:\Users\alayn\AppData\Local\Temp\ipykernel_36580\701153236.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   city_limit.area
# 0      0.009458
# 1      0.003588
# 2      0.000140
# 3      0.000112
# 4      0.000497
#          ...
# 951    0.004753
# 952    0.000396
# 953    0.001616
# 954    0.000258
# 955    0.000598
# Length: 956, dtype: float64

# %%
city_limit.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - onshore and offshore: Canada - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon. Puerto Rico. United States (USA) - Alabama; Alaska; Arizona; Arkansas; California; Colorado; Connecticut; Delaware; Florida; Georgia; Hawaii; Idaho; Illinois; Indiana; Iowa; Kansas; Kentucky; Louisiana; Maine; Maryland; Massachusetts; Michigan; Minnesota; Mississippi; Missouri; Montana; Nebraska; Nevada; New Hampshire; New Jersey; New Mexico; New York; North Carolina; North Dakota; Ohio; Oklahoma; Oregon; Pennsylvania; Rhode Island; South Carolina; South Dakota; Tennessee; Texas; Utah; Vermont; Virginia; Washington; West Virginia; Wisconsin; Wyoming. US Virgin Islands. British Virgin Islands.
# - bounds: (167.65, 14.92, -40.73, 86.45)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
city_limit_proj = city_limit.to_crs('EPSG:26916')

# %%
city_limit_proj.area
# Out:
# 0      1.026062e+08
# 1      3.843552e+07
# 2      1.533394e+06
# 3      1.195968e+06
# 4      5.528566e+06
#            ...
# 951    5.107429e+07
# 952    4.258012e+06
# 953    1.714939e+07
# 954    2.841791e+06
# 955    6.712851e+06
# Length: 956, dtype: float64

# %%
city_MBC = city_limit_proj.minimum_bounding_circle()

# %%
city_MBC.plot()
# Out:
# <Axes: >

# %%
city_MBC.area
# Out:
# 0      2.516707e+08
# 1      1.373781e+08
# 2      3.566088e+06
# 3      1.949856e+06
# 4      1.564862e+07
#            ...
# 951    1.361214e+08
# 952    9.421420e+06
# 953    3.149262e+07
# 954    6.798174e+06
# 955    2.057265e+07
# Length: 956, dtype: float64

# %%
city_ratio = city_limit_proj.area/city_MBC.area
print(city_ratio)
# Out:
# 0      0.407700
# 1      0.279779
# 2      0.429993
# 3      0.613362
# 4      0.353294
#          ...
# 951    0.375211
# 952    0.451950
# 953    0.544553
# 954    0.418023
# 955    0.326300
# Length: 956, dtype: float64

# %%
city_ratio.median()
# Out:
# np.float64(0.4112968688193812)

# %%
somewhat_circle_city_mask = city_ratio > 0.65
somewhat_circle_city = city_ratio[somewhat_circle_city_mask]
somewhat_circle_city
# Out:
# 61     0.659557
# 215    0.675540
# 579    0.672545
# 668    0.749481
# 670    0.672463
# dtype: float64

# %%
circle_cities = city_limit.iloc[somewhat_circle_city.index]
circle_cities
# Out:
#                                               geometry
# 61   POLYGON ((-85.53247 30.96609, -85.53128 30.966...
# 215  POLYGON ((-85.63154 30.98774, -85.6243 30.9874...
# 579  POLYGON ((-87.14324 30.564, -87.13586 30.56373...
# 668  POLYGON ((-81.21151 28.71957, -81.20577 28.724...
# 670  POLYGON ((-81.22464 28.59761, -81.22409 28.611...

# %%
fig, ax = plt.subplots(figsize=(10, 10))
circle_cities.plot(ax=ax, color='white', edgecolor='black')
plt.show()

# %%
circle_cities_names = city_name.iloc[circle_cities.index]
circle_cities_names
# Out:
#               NAME
# 61      Graceville
# 215           Noma
# 579          Mulat
# 668  Black Hammock
# 670     University
