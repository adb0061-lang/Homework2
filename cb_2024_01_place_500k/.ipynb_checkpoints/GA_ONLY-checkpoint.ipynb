# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
AL_Places = gpd.read_file("cb_2024_01_place_500k.shp")
print(AL_Places)
# Out:
#     STATEFP PLACEFP   PLACENS           GEOIDFQ    GEOID         NAME  \
# 0        01   32704  02403782  1600000US0132704  0132704   Haleyville
# 1        01   45472  02406131  1600000US0145472  0145472     McIntosh
# 2        01   53784  02406982  1600000US0153784  0153784      Newbern
# 3        01   78204  02405634  1600000US0178204  0178204       Valley
# 4        01   02836  02405172  1600000US0102836  0102836      Ashford
# ..      ...     ...       ...               ...      ...          ...
# 589      01   63984  02407191  1600000US0163984  0163984   Reece City
# 590      01   29296  02406555  1600000US0129296  0129296  Gaylesville
# 591      01   44536  02406051  1600000US0144536  0144536  Lowndesboro
# 592      01   55440  02407012  1600000US0155440  0155440    Notasulga
# 593      01   63495  02582695  1600000US0163495  0163495          Ray
#
#              NAMELSAD STUSPS STATE_NAME LSAD     ALAND  AWATER  \
# 0     Haleyville city     AL    Alabama   25  21713018  130983
# 1       McIntosh town     AL    Alabama   43   2579767       0
# 2        Newbern town     AL    Alabama   43   3010370    6872
# 3         Valley city     AL    Alabama   25  33384157       0
# 4        Ashford city     AL    Alabama   25  16064130   56699
# ..                ...    ...        ...  ...       ...     ...
# 589   Reece City town     AL    Alabama   43   9226254       0
# 590  Gaylesville town     AL    Alabama   43   3593015   94834
# 591  Lowndesboro town     AL    Alabama   43   2050742       0
# 592    Notasulga town     AL    Alabama   43  36173002  398501
# 593           Ray CDP     AL    Alabama   57  24506247  131245
#
#                                               geometry
# 0    MULTIPOLYGON (((-87.60417 34.24614, -87.60201 ...
# 1    POLYGON ((-88.03726 31.27171, -88.03112 31.271...
# 2    POLYGON ((-87.54125 32.60104, -87.52531 32.601...
# 3    MULTIPOLYGON (((-85.17006 32.7799, -85.17005 3...
# 4    POLYGON ((-85.25721 31.17963, -85.25643 31.204...
# ..                                                 ...
# 589  POLYGON ((-86.06752 34.04462, -86.0667 34.0452...
# 590  POLYGON ((-85.58281 34.2614, -85.58111 34.2593...
# 591  POLYGON ((-86.62132 32.27615, -86.61304 32.276...
# 592  POLYGON ((-85.7041 32.58211, -85.69565 32.5820...
# 593  POLYGON ((-86.08038 32.87669, -86.06123 32.891...
#
# [594 rows x 13 columns]

# %%
city_name = AL_Places[['NAME']]
city_limit = AL_Places[['geometry']]
print(city_name, city_limit)
# Out:
#             NAME
# 0     Haleyville
# 1       McIntosh
# 2        Newbern
# 3         Valley
# 4        Ashford
# ..           ...
# 589   Reece City
# 590  Gaylesville
# 591  Lowndesboro
# 592    Notasulga
# 593          Ray
#
# [594 rows x 1 columns]                                               geometry
# 0    MULTIPOLYGON (((-87.60417 34.24614, -87.60201 ...
# 1    POLYGON ((-88.03726 31.27171, -88.03112 31.271...
# 2    POLYGON ((-87.54125 32.60104, -87.52531 32.601...
# 3    MULTIPOLYGON (((-85.17006 32.7799, -85.17005 3...
# 4    POLYGON ((-85.25721 31.17963, -85.25643 31.204...
# ..                                                 ...
# 589  POLYGON ((-86.06752 34.04462, -86.0667 34.0452...
# 590  POLYGON ((-85.58281 34.2614, -85.58111 34.2593...
# 591  POLYGON ((-86.62132 32.27615, -86.61304 32.276...
# 592  POLYGON ((-85.7041 32.58211, -85.69565 32.5820...
# 593  POLYGON ((-86.08038 32.87669, -86.06123 32.891...
#
# [594 rows x 1 columns]

# %%
city_limit.plot()
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(10, 10))
city_limit.plot(ax=ax, color='white', edgecolor='black')
plt.show()

# %%
city_limit.area
# Out:
# C:\Users\alayn\AppData\Local\Temp\ipykernel_33808\701153236.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   city_limit.area
# 0      0.002138
# 1      0.000244
# 2      0.000289
# 3      0.003233
# 4      0.001524
#          ...
# 589    0.000905
# 590    0.000364
# 591    0.000196
# 592    0.003516
# 593    0.002377
# Length: 594, dtype: float64

# %%
city_limit.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - onshore and offshore: Canada - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon. Puerto Rico. United States (USA) - Alabama; Alaska; Arizona; Arkansas; California; Colorado; Connecticut; Delaware; Florida; Georgia; Hawaii; Idaho; Illinois; Indiana; Iowa; Kansas; Kentucky; Louisiana; Maine; Maryland; Massachusetts; Michigan; Minnesota; Mississippi; Missouri; Montana; Nebraska; Nevada; New Hampshire; New Jersey; New Mexico; New York; North Carolina; North Dakota; Ohio; Oklahoma; Oregon; Pennsylvania; Rhode Island; South Carolina; South Dakota; Tennessee; Texas; Utah; Vermont; Virginia; Washington; West Virginia; Wisconsin; Wyoming. US Virgin Islands. British Virgin Islands.
# - bounds: (167.65, 14.92, -40.73, 86.45)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
city_limit_proj = city_limit.to_crs('EPSG:26916')

# %%
city_limit_proj.area
# Out:
# 0      2.182938e+07
# 1      2.576485e+06
# 2      3.011000e+06
# 3      3.357408e+07
# 4      1.610881e+07
#            ...
# 589    9.262809e+06
# 590    3.717771e+06
# 591    2.046922e+06
# 592    3.660692e+07
# 593    2.465204e+07
# Length: 594, dtype: float64

# %%
city_MBC = city_limit_proj.minimum_bounding_circle()

# %%
city_MBC.plot()
# Out:
# <Axes: >

# %%
city_MBC.area
# Out:
# 0      1.336607e+08
# 1      5.249772e+06
# 2      4.957738e+06
# 3      1.940474e+08
# 4      2.539416e+07
#            ...
# 589    7.913342e+07
# 590    1.184372e+07
# 591    5.114317e+06
# 592    6.064219e+07
# 593    4.478678e+07
# Length: 594, dtype: float64

# %%
city_ratio = city_limit_proj.area/city_MBC.area
print(city_ratio)
# Out:
# 0      0.163319
# 1      0.490780
# 2      0.607334
# 3      0.173020
# 4      0.634351
#          ...
# 589    0.117053
# 590    0.313902
# 591    0.400234
# 592    0.603654
# 593    0.550431
# Length: 594, dtype: float64

# %%
city_ratio.median()
# Out:
# np.float64(0.39616510033419633)

# %%
somewhat_circle_city_mask = city_ratio > 0.65
somewhat_circle_city = city_ratio[somewhat_circle_city_mask]
somewhat_circle_city
# Out:
# 106    0.655340
# 111    0.696971
# 225    0.684512
# 256    0.972477
# 263    0.678664
# 271    0.692601
# 289    0.962458
# 383    0.945752
# 386    0.979160
# 478    0.657302
# 493    0.661002
# 525    0.665014
# 582    0.730783
# dtype: float64

# %%
circle_cities = city_limit.iloc[somewhat_circle_city.index]
circle_cities
# Out:
#                                               geometry
# 106  POLYGON ((-88.25904 33.41464, -88.2575 33.4175...
# 111  POLYGON ((-85.32422 32.7861, -85.32317 32.7896...
# 225  POLYGON ((-85.32452 31.25217, -85.32323 31.254...
# 256  POLYGON ((-87.4062 33.7147, -87.40521 33.71941...
# 263  POLYGON ((-86.69849 34.68405, -86.69179 34.684...
# 271  POLYGON ((-85.85529 31.0284, -85.85303 31.0301...
# 289  POLYGON ((-85.79284 33.08335, -85.79208 33.087...
# 383  POLYGON ((-85.91873 31.16804, -85.91764 31.170...
# 386  POLYGON ((-86.27405 31.58357, -86.27283 31.587...
# 478  POLYGON ((-88.05685 32.03335, -88.05259 32.046...
# 493  POLYGON ((-86.12246 32.84781, -86.12136 32.850...
# 525  POLYGON ((-87.5135 31.30892, -87.50565 31.3114...
# 582  POLYGON ((-85.51214 33.42414, -85.51088 33.424...

# %%
fig, ax = plt.subplots(figsize=(10, 10))
circle_cities.plot(ax=ax, color='white', edgecolor='black')
plt.show()

# %%
circle_cities_names = city_name.iloc[circle_cities.index]
circle_cities_names
# Out:
#                     NAME
# 106            Macedonia
# 111              Cusseta
# 225                 Webb
# 256               Oakman
# 263     Redstone Arsenal
# 271               Eunola
# 289            Goldville
# 383       Coffee Springs
# 386             Brantley
# 478               Putnam
# 493              Nixburg
# 525                Uriah
# 582  Morrison Crossroads
