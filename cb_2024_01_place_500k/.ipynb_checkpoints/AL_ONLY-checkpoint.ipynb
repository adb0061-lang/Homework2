# %%
import pandas as pd
import geopandas as gpd

# %%
AL_Places = gpd.read_file("cb_2024_01_place_500k.shp")
AL_Places.plot()
# Out:
# <Axes: >

# %%
print(AL_Places)
# Out:
#     STATEFP PLACEFP   PLACENS           GEOIDFQ    GEOID         NAME  \
# 0        01   32704  02403782  1600000US0132704  0132704   Haleyville
# 1        01   45472  02406131  1600000US0145472  0145472     McIntosh
# 2        01   53784  02406982  1600000US0153784  0153784      Newbern
# 3        01   78204  02405634  1600000US0178204  0178204       Valley
# 4        01   02836  02405172  1600000US0102836  0102836      Ashford
# ..      ...     ...       ...               ...      ...          ...
# 589      01   63984  02407191  1600000US0163984  0163984   Reece City
# 590      01   29296  02406555  1600000US0129296  0129296  Gaylesville
# 591      01   44536  02406051  1600000US0144536  0144536  Lowndesboro
# 592      01   55440  02407012  1600000US0155440  0155440    Notasulga
# 593      01   63495  02582695  1600000US0163495  0163495          Ray
#
#              NAMELSAD STUSPS STATE_NAME LSAD     ALAND  AWATER  \
# ...

# %%
City_limit = AL_Places[['NAME', 'geometry']]
print(City_limit)
# Out:
#             NAME                                           geometry
# 0     Haleyville  MULTIPOLYGON (((-87.60417 34.24614, -87.60201 ...
# 1       McIntosh  POLYGON ((-88.03726 31.27171, -88.03112 31.271...
# 2        Newbern  POLYGON ((-87.54125 32.60104, -87.52531 32.601...
# 3         Valley  MULTIPOLYGON (((-85.17006 32.7799, -85.17005 3...
# 4        Ashford  POLYGON ((-85.25721 31.17963, -85.25643 31.204...
# ..           ...                                                ...
# 589   Reece City  POLYGON ((-86.06752 34.04462, -86.0667 34.0452...
# 590  Gaylesville  POLYGON ((-85.58281 34.2614, -85.58111 34.2593...
# 591  Lowndesboro  POLYGON ((-86.62132 32.27615, -86.61304 32.276...
# 592    Notasulga  POLYGON ((-85.7041 32.58211, -85.69565 32.5820...
# 593          Ray  POLYGON ((-86.08038 32.87669, -86.06123 32.891...
#
# [594 rows x 2 columns]

# %%
print("hello world!")
# Out:
# hello world!
