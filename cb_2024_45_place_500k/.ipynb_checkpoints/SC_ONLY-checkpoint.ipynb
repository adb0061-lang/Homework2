# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
SC_Places = gpd.read_file("cb_2024_45_place_500k.shp")
print(SC_Places)
# Out:
#     STATEFP PLACEFP   PLACENS           GEOIDFQ    GEOID           NAME  \
# 0        45   06850  02405279  1600000US4506850  4506850       Blenheim
# 1        45   68470  02407388  1600000US4568470  4568470    Springfield
# 2        45   59920  02407206  1600000US4559920  4559920       Richburg
# 3        45   35890  02405893  1600000US4535890  4535890           Irmo
# 4        45   36610  02405909  1600000US4536610  4536610      Jefferson
# ..      ...     ...       ...               ...      ...            ...
# 470      45   75850  02405706  1600000US4575850  4575850  West Columbia
# 471      45   59425  02407197  1600000US4559425  4559425      Reidville
# 472      45   66760  02407347  1600000US4566760  4566760       Six Mile
# 473      45   50560  02407002  1600000US4550560  4550560          North
# 474      45   36475  02405903  1600000US4536475  4536475      Jamestown
#
#                NAMELSAD STUSPS      STATE_NAME LSAD     ALAND  AWATER  \
# 0         Blenheim town     SC  South Carolina   43   1692469       0
# 1      Springfield town     SC  South Carolina   43   4504598       0
# 2         Richburg town     SC  South Carolina   43   2269694       0
# 3             Irmo town     SC  South Carolina   43  17682503       0
# 4        Jefferson town     SC  South Carolina   43   4667360   14251
# ..                  ...    ...             ...  ...       ...     ...
# 470  West Columbia city     SC  South Carolina   25  24382483  441383
# 471      Reidville town     SC  South Carolina   43   4562219   55135
# 472       Six Mile town     SC  South Carolina   43   5277838   31000
# 473          North town     SC  South Carolina   43   2238170       0
# 474      Jamestown town     SC  South Carolina   43   1568673       0
#
#                                               geometry
# 0    POLYGON ((-79.66057 34.51667, -79.64487 34.515...
# 1    POLYGON ((-81.29212 33.49911, -81.2905 33.5023...
# 2    POLYGON ((-81.02984 34.71893, -81.02709 34.719...
# 3    MULTIPOLYGON (((-81.16108 34.05609, -81.15973 ...
# 4    POLYGON ((-80.40087 34.64686, -80.39796 34.647...
# ..                                                 ...
# 470  POLYGON ((-81.14722 34.0093, -81.14705 34.0094...
# 471  POLYGON ((-82.12776 34.87042, -82.11962 34.871...
# 472  MULTIPOLYGON (((-82.80564 34.81366, -82.80122 ...
# 473  MULTIPOLYGON (((-81.10943 33.60458, -81.10756 ...
# 474  POLYGON ((-79.70386 33.28508, -79.69556 33.294...
#
# [475 rows x 13 columns]

# %%
city_name = SC_Places[['NAME']]
city_limit = SC_Places[['geometry']]
print(city_name, city_limit)
# Out:
#               NAME
# 0         Blenheim
# 1      Springfield
# 2         Richburg
# 3             Irmo
# 4        Jefferson
# ..             ...
# 470  West Columbia
# 471      Reidville
# 472       Six Mile
# 473          North
# 474      Jamestown
#
# [475 rows x 1 columns]                                               geometry
# 0    POLYGON ((-79.66057 34.51667, -79.64487 34.515...
# 1    POLYGON ((-81.29212 33.49911, -81.2905 33.5023...
# 2    POLYGON ((-81.02984 34.71893, -81.02709 34.719...
# 3    MULTIPOLYGON (((-81.16108 34.05609, -81.15973 ...
# 4    POLYGON ((-80.40087 34.64686, -80.39796 34.647...
# ..                                                 ...
# 470  POLYGON ((-81.14722 34.0093, -81.14705 34.0094...
# 471  POLYGON ((-82.12776 34.87042, -82.11962 34.871...
# 472  MULTIPOLYGON (((-82.80564 34.81366, -82.80122 ...
# 473  MULTIPOLYGON (((-81.10943 33.60458, -81.10756 ...
# 474  POLYGON ((-79.70386 33.28508, -79.69556 33.294...
#
# [475 rows x 1 columns]

# %%
city_limit.plot()
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(10, 10))
city_limit.plot(ax=ax, color='white', edgecolor='black')
plt.show()

# %%
city_limit.area
# Out:
# C:\Users\alayn\AppData\Local\Temp\ipykernel_19752\701153236.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   city_limit.area
# 0      0.000169
# 1      0.000430
# 2      0.000217
# 3      0.001741
# 4      0.000459
#          ...
# 470    0.002438
# 471    0.000455
# 472    0.000523
# 473    0.000212
# 474    0.000151
# Length: 475, dtype: float64

# %%
city_limit.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - onshore and offshore: Canada - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon. Puerto Rico. United States (USA) - Alabama; Alaska; Arizona; Arkansas; California; Colorado; Connecticut; Delaware; Florida; Georgia; Hawaii; Idaho; Illinois; Indiana; Iowa; Kansas; Kentucky; Louisiana; Maine; Maryland; Massachusetts; Michigan; Minnesota; Mississippi; Missouri; Montana; Nebraska; Nevada; New Hampshire; New Jersey; New Mexico; New York; North Carolina; North Dakota; Ohio; Oklahoma; Oregon; Pennsylvania; Rhode Island; South Carolina; South Dakota; Tennessee; Texas; Utah; Vermont; Virginia; Washington; West Virginia; Wisconsin; Wyoming. US Virgin Islands. British Virgin Islands.
# - bounds: (167.65, 14.92, -40.73, 86.45)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
city_limit_proj = city_limit.to_crs('EPSG:26916')

# %%
city_limit_proj.area
# Out:
# 0      1.734704e+06
# 1      4.463128e+06
# 2      2.222075e+06
# 3      1.792984e+07
# 4      4.702843e+06
#            ...
# 470    2.515049e+07
# 471    4.637115e+06
# 472    5.320772e+06
# 473    2.198144e+06
# 474    1.581747e+06
# Length: 475, dtype: float64

# %%
city_MBC = city_limit_proj.minimum_bounding_circle()

# %%
city_MBC.plot()
# Out:
# <Axes: >

# %%
city_MBC.area
# Out:
# 0      3.769574e+06
# 1      4.568722e+06
# 2      3.460790e+06
# 3      1.295360e+08
# 4      7.166760e+06
#            ...
# 470    7.038184e+07
# 471    2.010977e+07
# 472    9.954293e+06
# 473    5.649242e+06
# 474    2.884104e+06
# Length: 475, dtype: float64

# %%
city_ratio = city_limit_proj.area/city_MBC.area
print(city_ratio)
# Out:
# 0      0.460186
# 1      0.976888
# 2      0.642072
# 3      0.138416
# 4      0.656202
#          ...
# 470    0.357344
# 471    0.230590
# 472    0.534520
# 473    0.389104
# 474    0.548436
# Length: 475, dtype: float64

# %%
city_ratio.median()
# Out:
# np.float64(0.4579565038841321)

# %%
somewhat_circle_city_mask = city_ratio > 0.65
somewhat_circle_city = city_ratio[somewhat_circle_city_mask]
somewhat_circle_city
# Out:
# 1      0.976888
# 4      0.656202
# 8      0.970924
# 11     0.987648
# 21     0.969419
# 28     0.947207
# 31     0.880805
# 33     0.951171
# 35     0.946441
# 40     0.989658
# 45     0.651545
# 57     0.784156
# 59     0.875254
# 78     0.922144
# 81     0.908078
# 83     0.943998
# 86     0.979420
# 88     0.943751
# 89     0.966416
# 91     0.953899
# 96     0.838224
# 97     0.946853
# 101    0.783111
# 107    0.687245
# 114    0.933478
# 116    0.971086
# 123    0.908122
# 133    0.978579
# 139    0.660947
# 152    0.949768
# 178    0.982730
# 196    0.973037
# 219    0.824351
# 224    0.665540
# 228    0.829168
# 266    0.976388
# 272    0.798512
# 284    0.883378
# 303    0.655096
# 317    0.678545
# 321    0.966091
# 327    0.853460
# 343    0.680547
# 373    0.683487
# 382    0.873653
# 397    0.954048
# 418    0.929169
# 457    0.872154
# dtype: float64

# %%
circle_cities = city_limit.iloc[somewhat_circle_city.index]
circle_cities
# Out:
#                                               geometry
# 1    POLYGON ((-81.29212 33.49911, -81.2905 33.5023...
# 4    POLYGON ((-80.40087 34.64686, -80.39796 34.647...
# 8    POLYGON ((-81.25483 34.80586, -81.25346 34.810...
# 11   POLYGON ((-82.70725 34.37963, -82.70583 34.382...
# 21   POLYGON ((-80.73226 33.56011, -80.73008 33.565...
# 28   POLYGON ((-81.26045 32.68232, -81.25925 32.685...
# 31   POLYGON ((-81.43433 33.92896, -81.42692 33.934...
# 33   POLYGON ((-81.12067 33.66868, -81.11976 33.671...
# 35   POLYGON ((-81.73234 34.21964, -81.73098 34.223...
# 40   POLYGON ((-81.03092 33.10006, -81.0299 33.1036...
# 45   POLYGON ((-80.44972 32.40734, -80.44491 32.411...
# 57   POLYGON ((-80.3587 34.4174, -80.3554 34.42193,...
# 59   POLYGON ((-80.85103 33.03762, -80.84871 33.039...
# 78   POLYGON ((-81.4291 34.2703, -81.42864 34.27134...
# 81   POLYGON ((-80.92739 33.43498, -80.92683 33.437...
# 83   POLYGON ((-81.73998 33.8582, -81.73866 33.8610...
# 86   POLYGON ((-81.31209 33.56925, -81.31005 33.572...
# 88   POLYGON ((-81.41786 35.04278, -81.41701 35.045...
# 89   POLYGON ((-81.13438 33.45358, -81.13298 33.455...
# 91   POLYGON ((-82.25622 34.29006, -82.25519 34.291...
# 96   POLYGON ((-81.61863 33.85008, -81.61552 33.855...
# 97   POLYGON ((-81.18319 33.22391, -81.1821 33.2264...
# 101  POLYGON ((-80.79058 33.66815, -80.78977 33.669...
# 107  POLYGON ((-79.76573 33.97294, -79.76467 33.977...
# 114  POLYGON ((-81.19371 33.18126, -81.19234 33.184...
# 116  POLYGON ((-80.97092 33.06796, -80.96966 33.073...
# 123  POLYGON ((-82.65581 34.21292, -82.65244 34.216...
# 133  POLYGON ((-81.2394 33.03891, -81.23764 33.0431...
# 139  POLYGON ((-79.75272 33.91899, -79.75121 33.921...
# 152  POLYGON ((-82.30577 33.99042, -82.30366 33.993...
# 178  POLYGON ((-81.35946 33.12826, -81.35794 33.131...
# 196  POLYGON ((-80.23505 34.77007, -80.2339 34.7733...
# 219  POLYGON ((-81.78853 34.00551, -81.7869 34.0087...
# 224  POLYGON ((-81.16133 33.90667, -81.16105 33.907...
# 228  POLYGON ((-80.8332 33.25381, -80.83223 33.2568...
# 266  POLYGON ((-81.26337 33.27699, -81.26267 33.279...
# 272  POLYGON ((-81.24429 34.87234, -81.24392 34.875...
# 284  POLYGON ((-81.22283 33.10387, -81.2223 33.1055...
# 303  POLYGON ((-80.49767 32.9389, -80.49708 32.9411...
# 317  POLYGON ((-81.3334 33.00447, -81.32496 33.0051...
# 321  POLYGON ((-81.20485 32.68315, -81.20344 32.687...
# 327  POLYGON ((-79.59488 34.6411, -79.59563 34.6439...
# 343  POLYGON ((-82.46444 34.72484, -82.46421 34.731...
# 373  POLYGON ((-78.98734 34.12894, -78.98246 34.127...
# 382  POLYGON ((-82.00147 34.30885, -82.00027 34.308...
# 397  POLYGON ((-81.12825 33.55416, -81.12723 33.556...
# 418  POLYGON ((-81.25376 32.95804, -81.25338 32.961...
# 457  POLYGON ((-79.97404 33.31171, -79.97155 33.316...

# %%
fig, ax = plt.subplots(figsize=(10, 10))
circle_cities.plot(ax=ax, color='white', edgecolor='black')
plt.show()

# %%
circle_cities_names = city_name.iloc[circle_cities.index]
circle_cities_names
# Out:
#                NAME
# 1       Springfield
# 4         Jefferson
# 8            Lowrys
# 11            Starr
# 21          Cameron
# 28           Scotia
# 31           Summit
# 33         Woodford
# 35     Silverstreet
# 40         Ehrhardt
# 45    Harbor Island
# 57          Bethune
# 59         Williams
# 78          Pomaria
# 81          Cordova
# 83             Ward
# 86           Salley
# 88           Smyrna
# 89           Norway
# 91           Hodges
# 96          Monetta
# 97            Govan
# 101    St. Matthews
# 107          Coward
# 114            Olar
# 116           Lodge
# 123    Lowndesville
# 133        Sycamore
# 139        Scranton
# 152            Troy
# 178           Kline
# 196   Mount Croghan
# 219          Saluda
# 224  South Congaree
# 228     Branchville
# 266           Hilda
# 272      McConnells
# 284           Ulmer
# 303    Cottageville
# 317       Allendale
# 321          Furman
# 327           Tatum
# 343    Golden Grove
# 373       Green Sea
# 382      Cross Hill
# 397      Livingston
# 418         Fairfax
# 457         Bonneau
